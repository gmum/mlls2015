# %%
# %matplotlib inline

import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd

from experiments.analyze import *

from misc.config import RESULTS_DIR
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 25 days

# %%
mtr = get_mean_time_reports(compound="5-HT1a_DUDs", fingerprint="Ext")
ptr = to_pandas(mtr)
ptr
# Out:
#                             QuasiGreedyBatch     CSJSampling  QueryByBagging  \
# total_time                   01:10:28.509192 00:50:51.017496 01:08:00.906960
# iter_time                    01:09:34.897345 00:49:45.533180 01:01:41.749991
# strategy_time                00:47:14.189868 00:17:05.139863 00:24:36.400605
# fit_time                     00:14:39.647764 00:19:11.167498 00:26:10.679192
# wac_score_time               00:02:35.757462 00:04:29.858147 00:03:52.266577
# wac_score_labeled_time       00:01:57.544213 00:03:30.865420 00:03:01.174965
# wac_score_unlabeled_time     00:01:24.486385 00:02:24.607448 00:01:40.915196
# wac_score_valid_time         00:00:33.405978 00:00:55.070075 00:00:46.079323
# wac_score_train_aleph_time   00:00:03.377304 00:00:03.557276 00:00:05.817548
# wac_score_valid_aleph_time   00:00:00.845098 00:00:00.902377 00:00:01.543194
# est_mon_time                 00:00:00.248769 00:00:00.256795 00:00:00.436599
# ...

# %%
mtr = get_mean_time_reports(compound="5-HT1a", fingerprint="Ext")
ptr = to_pandas(mtr)
ptr
# Out:
#                             QuasiGreedyBatch     CSJSampling  QueryByBagging  \
# total_time                   00:08:10.217536 00:05:25.005536 00:10:39.113482
# iter_time                    00:07:50.012198 00:05:01.963659 00:10:10.681841
# strategy_time                00:04:21.417072 00:01:11.509494 00:03:49.436210
# fit_time                     00:02:35.398273 00:02:51.175595 00:03:32.729013
# wac_score_time               00:00:18.184822 00:00:20.374917 00:00:59.324451
# wac_score_labeled_time       00:00:13.941079 00:00:15.497363 00:00:46.044797
# wac_score_unlabeled_time     00:00:08.534347 00:00:09.404683 00:00:27.367478
# wac_score_valid_time         00:00:03.955335 00:00:04.395217 00:00:06.943622
# wac_score_train_aleph_time   00:00:01.018467 00:00:01.151920 00:00:01.254044
# wac_score_valid_aleph_time   00:00:00.290850 00:00:00.330008 00:00:00.349760
# est_mon_time                 00:00:00.131628 00:00:00.145664 00:00:00.166400
# ...
